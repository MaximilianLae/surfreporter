# %%
import json
import pandas as pd

# Load the JSON file
with open('data/surf_spots_enriched.json', 'r') as file:
    surf_spots_data = json.load(file)

# Flatten the nested JSON structure and convert to a DataFrame
surf_spots_df = pd.json_normalize(surf_spots_data, sep='_')

# %%
import pandas as pd
import itertools

# Define wave direction and bottom type mappings
direction_mapping = {
    "Left and right": ["Left", "Right", "Left and right"],
    "Left": ["Left"],
    "Right": ["Right"]
}

bottom_mapping = {
    "Sand, Sand with rocks": ["Sand", "Sand with rocks", "Sand, Sand with rocks"],
    "Sand with rocks, Reef": ["Sand with rocks", "Reef", "Sand with rocks, Reef"],
    "Reef": ["Reef"],
    "Sand": ["Sand"],
    "Sand with rocks": ["Sand with rocks"],
    "Sand, Reef": ["Sand", "Reef", "Sand, Reef"],
    "Sand, Sand with rocks, Reef": ["Sand", "Sand with rocks", "Reef", "Sand, Sand with rocks, Reef"]
}

# %%
# List all metadata combinations
directions = list(direction_mapping.keys())
bottoms = list(bottom_mapping.keys())

# Initialize storage for the dataset
ground_truth_data = []

# Loop through metadata combinations
for direction, bottom in itertools.product(directions, bottoms):
    # Get relevant subcategories
    relevant_directions = direction_mapping[direction]
    relevant_bottoms = bottom_mapping[bottom]

    # Filter dataset based on metadata combination
    filtered_df = surf_spots_df[
        surf_spots_df['details_Direction of Wave'].isin(relevant_directions) &
        surf_spots_df['details_Type of Bottom'].isin(relevant_bottoms)
    ]

    # Collect spot descriptions
    descriptions = filtered_df['details_Spot Description'].tolist()

    if descriptions:  # Only process if there are descriptions for this combination
        ground_truth_data.append({
            "Direction of Wave": direction,
            "Type of Bottom": bottom,
            "Descriptions": descriptions
        })

# Convert to DataFrame
ground_truth_df = pd.DataFrame(ground_truth_data)

# %%
from openai import OpenAI
import json
import time
import pandas as pd
from config import OPENAI_API_KEY

# Initialize OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

def generate_ground_truth_queries(direction, bottom, descriptions, model="gpt-4o-mini", max_retries=3):
    """
    Generate user queries and corresponding expected answers using OpenAI GPT-4o-mini.
    """
    # Prepare descriptions as a structured text input
    descriptions_text = "\n".join([f"- {desc}" for desc in descriptions])

    # Define the prompt
    messages = [
        {"role": "system", "content": "You are an expert surf advisor, generating realistic user queries and their expected responses for an AI-powered surf spot recommendation system."},
        {
            "role": "user",
            "content": f"""
Make sure to use only information from the retrieved spots and do not hallucinate.
Based on the following surf spots that match these conditions:
- Wave Direction: {direction}
- Bottom Type: {bottom}

Spot Descriptions:
{descriptions_text}

Please generate 10 user queries related to all the specific spots. For each query, also provide an ideal answer that sounds like a surf report for these spots in a natural way. Make sure to use only information from the retrieved spots and do not hallucinate.

Return the result as **valid JSON** with exactly two keys: 
- "queries" (a list of 10 questions a surfer might ask)
- "answers" (a list of 10 corresponding responses that an AI surf report would generate).

Example JSON format:
{{
    "queries": ["I want to surf relaxed waves with sand bottom this weekend", "I would like to surf punchy beach breaks barrels"],
    "answers": ["Praia Azul offers left-hand waves on a sandy bottom, best surfed at mid-tide and has mellow waves", "Carcavelos offers great waves for your preferences, having a variety of peaks and punchy waves."]
}}
"""
        }
    ]

    # Implement retry logic for API failures
    for attempt in range(max_retries):
        try:
            completion = client.chat.completions.create(
                model=model,
                messages=messages
            )

            # Extract response text
            response_text = completion.choices[0].message.content

            # Try parsing JSON output
            parsed_response = json.loads(response_text)

            # Ensure required keys exist
            if "queries" in parsed_response and "answers" in parsed_response:
                return parsed_response
            else:
                print(f"Invalid response structure on attempt {attempt + 1}: {response_text}")
        
        except json.JSONDecodeError:
            print(f"JSON parsing failed on attempt {attempt + 1}. Response: {response_text}")

        except Exception as e:
            print(f"API Error on attempt {attempt + 1}: {e}")
        
        # Exponential backoff before retrying
        time.sleep(2 ** attempt)  

    return None  # Return None if all retries fail


# Apply LLM to each metadata combination
ground_truth_with_queries = []

for _, row in ground_truth_df.iterrows():
    response = generate_ground_truth_queries(
        direction=row["Direction of Wave"],
        bottom=row["Type of Bottom"],
        descriptions=row["Descriptions"]
    )
    
    if response:
        for query, answer in zip(response["queries"], response["answers"]):
            ground_truth_with_queries.append({
                "Direction of Wave": row["Direction of Wave"],
                "Type of Bottom": row["Type of Bottom"],
                "Query": query,
                "Expected Answer": answer
            })

# Convert to DataFrame
final_truth_df = pd.DataFrame(ground_truth_with_queries)

# Save results
final_truth_df.to_csv("ground_truth_rag_surf.csv", index=False)
final_truth_df.to_json("ground_truth_rag_surf.json", orient="records", indent=4)

print("Ground truth dataset successfully created and saved.")
# Out:
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "Where can I find less crowded waves with both lefts and rights nearby?",
#         "What's a good spot for beginners looking for sandy bottom waves?",
#         "Are there any intermediate-friendly surf spots with consistent waves?",
#         "Which beaches offer fun left and right breaks around Lisbon?",
#         "Can you recommend a place to surf with multiple peaks breaking over sand?",
#         "What's the best tide to surf at Praia da Almagreira?",
#         "Where can I find an uncrowded spot with good sand bottom waves?",
#         "Is there a beach break that works well for both beginners and pros?",
#         "What surf spot should I check if I want a solid left tube?",
#         "Where can I find a quality wave with less localism?"
#     ],
#     "answers": [
#         "Praia do Baleal Norte is ideal for escaping the crowds, offering both lefts and rights across its sandy beach. The wave quality improves significantly when the sandbanks align just right.",
#         "For beginners, Prainha at Praia do Baleal Norte is a fantastic choice. It has forgiving waves breaking mostly over a sandy bottom, making it perfect for learning.",
#         "Foz do Lizandro is excellent for intermediates with its consistent beach breaks and multiple peaks, accessible at mid-low tide for the best experience.",
#         "Costa da Caparica is a great option as it boasts numerous beaches where you can find fun left and right breaks that suit a range of surf levels.",
#         "Praia da Peralta features multiple peaks that break mostly over sand, providing several options for fun lefts and rights, making it a good spot to explore.",
#         "You can surf at Praia da Almagreira from mid-high tide to high tide, where the longer lefts are generally more enjoyable.",
#         "Foz do Sizandro is a great choice if you're looking for a less crowded spot with good sandy bottom waves. It caters to all levels and is best surfed around low tide.",
#         "Praia Grande is versatile, with waves that cater to both beginners during smaller conditions and advanced surfers when the swell picks up. Its multiple peaks allow for everyone to find their place.",
#         "If you're in search of a solid left tube, Praia da Peralta has 'The Bunker' on the south side, known for producing amazing tubes, but be aware it's mostly for local experts.",
#         "For a quality wave with lower localism, Praia da Almagreira is a good bet. It’s less crowded and offers fun, consistent waves, particularly for intermediate to expert surfers."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "What are the best spots for intermediate surfers looking for sand bottom waves?",
#         "Can you recommend a place with consistent left and right waves?",
#         "Is there a less crowded spot near Peniche for surfing this weekend?",
#         "What surf spot is suitable for all surf levels with both lefts and rights?",
#         "Where can I find some fun beach breaks with moderate consistency?",
#         "Which surf spot has the best conditions during mid to high tide?",
#         "Are there any beginner-friendly surf spots along the coast?",
#         "What beach breaks near Lisbon have good facilities for surfers?",
#         "Where can I find a scenic surf spot with lower crowds?",
#         "What places around Ericeira are good for enjoying varied surf conditions?"
#     ],
#     "answers": [
#         "Praia da Almagreira is a great option for intermediate surfers, offering fun and consistent waves over a mostly sandy bottom. It's ideal for those looking to escape the crowds of Peniche. Other good spots include Foz do Lizandro and Praia de Valmitão, both of which cater to intermediate surfers too.",
#         "Foz do Lizandro has a mix of lefts and rights, especially in the middle where the waves are fun and easy to surf. On bigger days, the lefts at the river mouth can be your best bet. Another good option is Praia do Baleal Norte, known for its versatile peaks.",
#         "For a less crowded surf experience near Peniche, check out Praia da Almagreira. It offers consistent waves and a beautiful, isolated beach atmosphere. Another option could be Praia do Pico da Mota, which also has fun waves without the hustle.",
#         "Praia da Peralta is an excellent option for all surf levels with both lefts and rights, famed for its less crowded conditions and multiple peaks. Foz do Lizandro also welcomes all surfers, making it versatile for every skill level.",
#         "Praia do Guincho and Praia de Valmitão both provide sandy beach breaks with moderate consistency. Both spots are suitable depending on the swell conditions and can offer fun waves for the day.",
#         "Praia da Adraga offers an appealing surf environment with moderate consistency, making it ideal during mid to high tide when the waves are fun and aligned. On tides, Foz do Lizandro also becomes accessible around this time for great waves.",
#         "If you are looking for beginner-friendly surf spots, consider Praia Pequena or Praia do Baleal Sul. Both offer easy waves suitable for learning and are protected from strong winds, allowing for a comfortable surf experience.",
#         "Costa da Caparica is a surfer's paradise not far from Lisbon, providing excellent surf with well-maintained facilities like parking areas and cafes. Another great option is Praia da Carcavelos, known for its various peaks and surfer-friendly setups.",
#         "For scenic surf spots with lower crowd levels, check out Praia da Adraga. It’s surrounded by stunning nature and provides good waves without heavy foot traffic. Similarly, Foz do Sizandro offers a beautiful coastline with solid surf potential.",
#         "Santa Cruz and its neighboring breaks offer a variety of peaks with lefts and rights, making them great for enjoying diverse surf conditions. You can also find quality waves at Foz do Sizandro when the winds and swells align."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "Which surf spot near Peniche has both lefts and rights with a sandy bottom?",
#         "I’m looking for a beach with consistent waves for intermediate to expert surfers. Any suggestions?",
#         "Where can I find less crowded surf conditions with good left tubes?",
#         "Is there a surf spot with both sand and some rocks that’s good for all levels?",
#         "What’s a good surf beach with multiple peaks and an easier vibe near Lisbon?",
#         "Can you recommend a spot with a nice left-hander and fun waves without heavy crowds?",
#         "Where would I find a quality wave with both lefts and rights, suitable for beginners?",
#         "I want to surf at a spot that offers fun waves but has some shelter from the wind; what do you suggest?",
#         "Which beach has good facilities and works well for different tide conditions?",
#         "Can you tell me about a spot that’s good for longboarders and has both left and right waves?"
#     ],
#     "answers": [
#         "Praia da Almagreira, just north of Baleal and Peniche, offers fun and consistent lefts and rights with a sandy bottom, great for intermediate to expert surfers. Watch out for the odd rocks at lower tide.",
#         "Foz do Lizandro is a fantastic choice for you, providing very consistent waves suitable for all surf levels, with both lefts and rights and a sandy bottom.",
#         "Check out Praia da Peralta for the chance to catch amazing left tubes, especially known as 'The Bunker'. It tends to be less crowded, making it perfect for a more relaxed session.",
#         "Praia do Baleal Sul is an excellent beach with multiple peaks, breaking over both sand and occasional rocky areas. It's suitable for all levels, making it a versatile choice.",
#         "Costa da Caparica fits your criteria perfectly, with many beach breaks suitable for all surf levels and a more relaxed vibe if you venture south from the busy center.",
#         "Praia da Adraga features fun consistent left-handers in beautiful surroundings and can offer a good vibe due to its less crowded situation, especially appealing for those seeking a mellow surf experience.",
#         "Praia Pequena is a great option for beginners, offering consistent surf with both lefts and rights breaking over sand. It's a fantastic choice with a welcoming atmosphere.",
#         "Praia do Guincho is known for its powerful waves but provides some shelter depending on the wind direction. It offers fun waves that can suit a range of abilities.",
#         "Praia da Carcavelos has excellent facilities and works well at all tides, giving you plenty of options for surf sessions with both left and right peaks available.",
#         "For longboarders, Gigi just north of Lagide is perfect, offering both lefts and rights while being less crowded, ideal for those looking to enjoy a more gentle ride."
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "What surf spot offers both lefts and rights and is suitable for beginners?",
#         "Where can I find less crowded surf spots with both sand and reef breaks?",
#         "Which surf spot has a heavy localism but suitable waves for intermediate surfers?",
#         "Is there a spot with powerful barrels that works at mid tide?",
#         "Can you recommend a surf break with a mix of waves suitable for advanced surfers?",
#         "What spot should I check out if I want a mellow wave with good timing?",
#         "Where are the best places for a left only, where I won’t have too many surfers around?",
#         "What’s the safest spot for intermediates with a higher tide and good wave quality?",
#         "Which surf spot has fun and consistent waves from mid to high tide?",
#         "Is there a surf break that’s good for both longboarders and shortboarders?"
#     ],
#     "answers": [
#         "Praia da Cresmina is perfect for you, offering both lefts and rights, with a sand and rock bottom, suitable for all levels from beginner to expert during mid tide.",
#         "You'll want to check out Praia da Azarujinha, known for its less crowded conditions and fun waves. It features a reef break and typically works best around mid tide.",
#         "Moita at Praia de São Sebastião is what you’re looking for! It's known for its heavy localism while providing suitable waves for intermediate surfers, breaking around mid to high tide.",
#         "Praia de Santo Amaro is a must-visit for powerful barrels, particularly during mid tide when the conditions are just right. It's best suited for advanced surfers only!",
#         "For advanced surfers, Matadouro offers a mix of mellow lefts and quality rights, surfable from mid to high tide, making it a diverse choice.",
#         "Try Praia da Calada, which features both lefts and rights over a reef and has mellow waves that beginners can enjoy; just need to choose the right timing.",
#         "Praia do Norte features solid lefts, and with its moderate crowd, you can enjoy some zen surfing without too many competitors around.",
#         "Backdoor is a great option for intermediates since it works well with mid to high tide and offers a variety of quality waves that are manageable.",
#         "You should definitely visit Ribeira d’Ilhas as it’s known for fun and consistent waves, best surfed during mid tide and suitable for all levels.",
#         "Bico provides an excellent blend of waves for both longboarders and shortboarders alike, offering a mellow right on a point break that works best during mid-low tide."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "What spots are good for both lefts and rights with sand bottoms?",
#         "Can you recommend a less crowded surf spot with a reef break?",
#         "Where can I find consistent waves for intermediate surfers this weekend?",
#         "What are the best places to catch left-handers in the area?",
#         "I'm looking for a fun reef break that's not too competitive, any suggestions?",
#         "Which surf spots are best during mid-tide?",
#         "Are there any good local spots with a moderate crowd factor?",
#         "Where can I surf a mix of beach and reef breaks with a mellow vibe?",
#         "What spot has good waves and is suitable for beginners this time of year?",
#         "Can you tell me about a local favorite for advanced surfers near Ericeira?"
#     ],
#     "answers": [
#         "Praia da Poça is a great option for you, offering both lefts and rights with a combination of sandy and rocky bottoms, particularly suitable during mid-tide.",
#         "Praia da Cresmina is less crowded than others and features a mix of reef and beach breaks. It's a fantastic spot for catching waves without too much competition.",
#         "Ribeira d'Ilhas is consistently perfect for intermediate surfers, with accessible waves and facilities, particularly good around mid-tide.",
#         "If you're looking for left-handers, Pedra Branca is a top choice. It's a powerful reef break offering thrilling, fast lefts, and can be fun with the right swell.",
#         "Paparucos is a perfect spot for those seeking fun and mellower reef breaks. With easier access and moderate waves, it's great for intermediate surfers.",
#         "Matadouro is known for its nice mellow lefts and rights, working best around mid-tide, making it ideal for most levels.",
#         "Consider Praia da Azarujinha if you're looking for a local spot with a moderate crowd factor. It has solid waves for intermediate to expert surfers.",
#         "Cave offers a mix of reef and beach breaks with a mellow vibe, great for those looking to avoid the hustle and bustle at busier spots.",
#         "Praia de São Sebastião provides a good variety for beginners, particularly with the right conditions during mid-tide making it accessible and fun.",
#         "Coxos is a local favorite for advanced surfers, known for its powerful right-hand point break. It's consistent and the waves offer plenty of challenge!"
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "Where can I find a less crowded surf spot with both left and right waves?",
#         "I'm looking for a place to surf that has a mix of reef and beach breaks.",
#         "Can you recommend a beginner-friendly surf spot with both lefts and rights?",
#         "What are some good surf spots in Ericeira suitable for intermediate surfers?",
#         "What's the consistency of waves at Praia da Cresmina?",
#         "Are there any surf spots with high localism I should know about?",
#         "Where can I find quality lefthanders near Algodio?",
#         "I'm looking for a surf spot that works well with mid-tide and has both lefts and rights.",
#         "Can you tell me about any surf spots with a sand bottom and rocky formations?",
#         "What's the best time to surf at Praia de Santo Amaro?"
#     ],
#     "answers": [
#         "Praia da Cresmina is a great option for less crowded waves, with both lefts and right peaks available. It's a mix of a beach and reef break and typically sees fewer surfers compared to larger spots.",
#         "For a mix of reef and beach breaks, Matadouro is a solid choice. It features nice mellow lefts and better quality rights, offering something for everyone.",
#         "Praia da Cresmina and Matadouro are both accessible for beginner surfers. Cresmina has a mix of peaks, while Matadouro offers an inside reform break suitable for newcomers.",
#         "In Ericeira, Riberia d'Ilhas is perfect for intermediates, providing a long and mellow right-hand point break that often has multiple peaks. You might also consider Paparucos or Praia da Cresmina.",
#         "Praia da Cresmina, while offering moderate wave consistency, is less crowded than its counterparts, making it ideal for a relaxed surf session.",
#         "Moita, located just north of Algodio Beach, is known for its heavy localism and should be approached with respect to avoid any issues with locals.",
#         "If you’re after quality lefthanders near Algodio, look at Praia da Azarujinha. It offers fun waves over a reef and is best around mid tide.",
#         "For conditions that work well with mid-tide and offer both lefts and rights, both Matadouro and Praia da Cresmina have you covered. They're known for delivering fun rides.",
#         "For a mix of a sandy bottom and rocks, check out Praia do Magoito which features both lefts and rights. It's a fun place to surf with a good vibe.",
#         "Praia de Santo Amaro typically works best during mid to high tide, especially when the swells are significant, making it a thrilling ride for advanced surfers."
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "What are the best surf spots with reef bottoms around Ericeira for left and right waves?",
#         "Can you recommend a good surf spot for intermediate surfers that has lefts and rights?",
#         "What's a less crowded reef break for expert surfers in the Ericeira area?",
#         "Where can I find mellow wave options between rip currents and rocky areas?",
#         "What spot would be suitable for advanced surfers looking to ride both left and right waves?",
#         "Can you suggest a surf spot with strong localism that has consistent left and right waves?",
#         "What are the tide conditions for 'Coxos' and 'Paparucos'?",
#         "Are there any reef breaks around Ericeira that work well with mid tide?",
#         "I'd like to surf a spot that offers both hollower tubes and longer rides, any recommendations?",
#         "Which surf spot in Ericeira would be ideal for pro surfers looking for powerful waves?"
#     ],
#     "answers": [
#         "Paparucos and Matadouro both feature reef bottoms and can offer fun lefts and rights. Paparucos is best during mid to high tide, while Matadouro is accessible for all levels with better waves around mid to high tide.",
#         "For intermediates, I'd suggest Matadouro. It offers nice mellow lefts and better quality rights, with surfable conditions from mid-high tide.",
#         "Check out 'Cave' for a truly expert experience. It's known for being heavy and difficult, providing powerful right barrels, but it strictly requires pro skill. Also, 'Paparucos' could be an option for experts looking for a fun challenge.",
#         "Matadouro provides accessible waves for all skill levels but be cautious of rip currents. The lefts and rights are perfect at mid-high tide, and make sure to scout the area for easier exits.",
#         "Moita has both left and right options suited for advanced surfers, but take heed of the heavy localism. The wave works well at mid to high tide, offering good, forgiving sections.",
#         "If you want a spot with strong localism, consider Moita. It has a very high sense of localism with consistent waves but is only suitable for advanced to expert surfers, especially considering the heavy local crowd.",
#         "Coxos typically works best at low to mid tide and features some long, fast right-hand barrels. Paparucos is best surfed at mid to high tide with its easy-going wave characteristics.",
#         "For mid tide reef breaks, 'Limipicos' and 'Lagide' are great. Limipicos works best mid-high tide while Lagide can deliver both lefts and rights, with its better waves typically arriving around mid tide.",
#         "Coxos is an ideal spot when you want both hollower tubes and long rides. It offers multiple barrel sections and can hold big swells, making it a favorite among pros.",
#         "For pro surfers, 'Cave' and 'Crazy Left' are excellent choices in Ericeira. Both spots offer powerful waves and are best surfed at mid-high tide, though they require solid skills due to their intensity."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "What is the best surf spot for left and right waves over a reef near Ericeira?",
#         "Can you recommend a surf spot with moderate consistency and a low sense of localism?",
#         "Where should I go for powerful barrels on a reef during mid tide?",
#         "I am an intermediate surfer; which reef break would suit my level best?",
#         "What surf spot would you recommend for advanced surfers who want to avoid crowds?",
#         "Is there a spot with good waves at mid tide for expert surfers?",
#         "What spot should I choose if I want to surf an a-frame with both left and right waves?",
#         "I want to surf a spot with high localism; any recommendations for pro surfers?",
#         "What are some accessible reef breaks with a fun vibe for intermediate-advanced surfers?",
#         "Which surf spot has the best barrels and is suitable for pro surfers?"
#     ],
#     "answers": [
#         "Paparucos offers both left and right waves over a reef, suitable for intermediate to expert surfers, with moderate consistency and a high crowd factor. Ideal when surfed at mid to high tide.",
#         "Matadouro is a great spot that features both lefts and rights over a reef with a low sense of localism and moderate crowd. It can be surfed from mid to high tide, making it a good option for all levels.",
#         "Praia de Santo Amaro is your best bet for powerful barrels over a reef during mid tide. It's a challenging spot best suited for advanced surfers and has low crowds when conditions are good.",
#         "For intermediate surfers, Papucos is a good choice. It breaks over a flat rock bottom and provides mellow waves with opportunities to build skills. Best surfed at mid tide.",
#         "For advanced surfers looking to escape the crowds, Backdoor is a reliable choice. It offers an easy-to-surf right over a reef, working best at mid tide, allowing for a more solitary surf session.",
#         "If you're an expert surfer looking for quality waves, look no further than the Reef surf spot. It shows its true potential at mid tide, offering fast, hollow rights perfect for skilled surfers.",
#         "At Algodio beach, you'll find Moita, an a-frame featuring both lefts and rights. With its moderate consistency, it's accessible for good intermediates and best surfed from mid to high tide.",
#         "Coxos is renowned for being a pro surfer's playground, featuring heavy localism and offering incredible barrels. This powerful right point break is best surfed during low to mid tide.",
#         "Limipicos is a solid spot for intermediate to expert surfers looking for a fun vibe. It breaks over a flat stone reef and can be enjoyed during mid to high tide under the right conditions.",
#         "Pedra Branca is your go-to for the best barrels, offering a powerful left over a shallow reef. Best suited for pros, this spot requires respect for the locals and works well at mid-high tide."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "What spots are best for surfing left and right reef breaks this weekend?",
#         "Can you recommend a spot for good barrel waves for advanced surfers?",
#         "I'm looking for a surf spot that works at mid to high tide and has a mix of lefts and rights.",
#         "Are there any beginner-friendly reef breaks around?",
#         "Where can I find consistent waves with low crowds?",
#         "What's the best surf spot near Ericeira with high localism and powerful waves?",
#         "Which surf spots have the best conditions for advanced surfers this October?",
#         "What's the crowd situation like at Praia de Santo Amaro?",
#         "Could you suggest a reef break that offers both hollow lefts and rights?",
#         "I want to surf a powerful wave this weekend. Any suggestions?"
#     ],
#     "answers": [
#         "For the upcoming weekend, you should check out spots like Paparucos and Moita, as they both offer both left and right reef breaks. Paparucos is best surfed at mid to high tide, while Moita works well from mid to high tide as well.",
#         "If you're seeking barrel waves, Pedra Branca is the place to be. It offers fast, powerful left-hand tubes over a shallow reef, perfect for experienced surfers looking for that thrill!",
#         "Check out Matadouro and Paparucos, as both can be surfed at mid to high tide with a mix of left and right waves. Matadouro is great for all surf levels, making it a fun spot for everyone!",
#         "Matadouro is an excellent choice for beginners looking to experience reef breaks, particularly on the inside reform where it can be surfed safely during mid to high tide.",
#         "You might want to consider Praia de Santo Amaro; it has low crowds and offers consistent waves, great for pro surfers, especially from mid tide onwards.",
#         "For an experience with high localism and powerful waves, look into Coxos. It’s considered one of the best in the world, but only for the experienced as it can get quite heavy.",
#         "This October, Pedra Branca and Cave are ideal for advanced surfers, both providing powerful and intense conditions ideally surfed during mid to high tide.",
#         "Praia de Santo Amaro often has low crowds, especially if you catch it during the right swell season, perfect for experienced surfers looking to avoid busy lineups.",
#         "Lagide or Ponte do Futuro both provide good options for hollow lefts and rights, with Lagide being more accessible with an a-frame reef break.",
#         "For a powerful wave experience this weekend, you should head to Inatel or Cave. Both spots cater to advanced surfers looking for challenging conditions with exciting breaks!"
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "Where can I find consistent beach breaks suitable for beginners?",
#         "What's the best surf spot with both lefts and rights in the Ericeira area?",
#         "Is there a surf spot with fun waves for all levels near Lisbon?",
#         "Can you recommend a sandy beach break with good facilities?",
#         "Which surf spot has the best conditions from low to mid tide?",
#         "What are some less crowded surf spots near Peniche?",
#         "Where can I find mellow waves with sandy bottoms for beginners?",
#         "Are there beach breaks that hold up best during the winter months?",
#         "Which spots have a high crowd factor but are still beginner-friendly?",
#         "What surf spot should I check if I want to avoid strong rip currents?"
#     ],
#     "answers": [
#         "Foz do Lizandro is a great choice for consistent beach breaks, especially for beginners. The sandy bottom makes for safe surfing, and the waves are typically fun and easy to ride.",
#         "You should check out Foz do Lizandro, which not only has lefts but also rights with its varied peaks, particularly nice on the south side and in the middle.",
#         "Costa da Caparica is an excellent spot for fun waves suitable for all levels with its long stretch of beach breaks. Explore a bit south for less crowded conditions.",
#         "Foz do Lizandro offers great facilities with a good car park, showers, and cafes, making it a great spot to surf comfortably.",
#         "For the best conditions from low to mid tide, head to Foz do Lizandro where the waves generally work best during those times.",
#         "If you're looking for less crowded options near Peniche, consider checking Praia do Baleal Sul, where you can find fun waves without the heavy crowds.",
#         "Praia dos Pescadores is perfect for beginners seeking mellow waves over a sandy bottom, particularly great during low tide with larger swells.",
#         "Praia da Torre offers decent waves during the winter months, although it needs a bigger swell to start working well compared to other spots.",
#         "Carcavelos is very popular and can get crowded, but it's still beginner-friendly with multiple peaks and options for all surf levels.",
#         "If you're concerned about strong rip currents, Praia dos Pescadores can be a safer option as it offers mellow waves, but be cautious of the currents on bigger days."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "Where can I find a beach break with left and right waves that's suitable for beginners?",
#         "What surf spots are there near Lisbon with sandy bottoms?",
#         "I'm looking for consistent waves to surf after work on weekdays. Any suggestions?",
#         "What are the best spots around Ericeira for all surf levels on the weekends?",
#         "Can you recommend a non-crowded surf spot with fun waves and multiple peaks?",
#         "Which beach break is best for surf schools and novice surfers?",
#         "What places have waves that suit all skill levels and are open year-round?",
#         "I'd like to surf somewhere with powerful barrels but also options for smaller waves. Where should I go?",
#         "Are there any lesser-known surf spots in Peniche that are suitable for all levels?",
#         "What's the best surf spot for left-handed waves in the Lisbon area?"
#     ],
#     "answers": [
#         "Foz do Lizandro is a great choice! It has both lefts and rights on a sandy bottom, making it ideal for beginners. You can enjoy fun and easy waves, especially from low to mid tide.",
#         "Costa da Caparica and Praia Grande are your best bets for sandy-bottom beach breaks near Lisbon. Both spots cater to various skill levels and can work in different conditions throughout the year.",
#         "Praia Grande offers consistent waves that are perfect for after-work sessions. With its versatility and multiple peaks, you can find fun waves at mid to high tide.",
#         "For a variety of surf conditions suitable for all levels, check out Foz do Lizandro and Costa da Caparica. Both spots tend to have a crowd, but they're reliable for any weekend session.",
#         "Consider Praia da Torre or the surfer-friendly Pico da Mota. They offer fun waves with less crowd compared to more popular spots, ideal for a relaxed surf experience.",
#         "Check out Foz do Lizandro, as it's popular among surf schools for its sandy bottom and easy waves, making it perfect for novice surfers looking to learn.",
#         "Costa da Caparica is excellent for year-round surfing, providing options for all levels throughout the seasons. Foz do Lizandro is also a consistent choice.",
#         "If you're looking for powerful barrels, Supertubos is world-class. For smaller and more manageable waves, you can find good conditions at Foz do Lizandro and Praia Grande.",
#         "For a less crowded surf experience in Peniche, try Praia do Baleal Sul. It has multiple peaks that cater to all surf levels, with fun, smaller waves for beginners.",
#         "You should head to Foz do Lizandro for left-handed waves. The left at the river mouth is often the best option when the conditions are right."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "Where can I find consistent beach breaks with both lefts and rights?",
#         "I'm a beginner looking for a sandy-bottom surf spot; any recommendations?",
#         "What are the best surf spots near Lisbon that work at different tides?",
#         "Can you suggest a less crowded beach break for intermediate surfers?",
#         "Which surf spot has the best conditions for long and hollow lefts?",
#         "I'm traveling with friends; where's a good spot for mixed surf levels?",
#         "Where can I find a versatile beach break with several peaks?",
#         "Is there a recommendation for a surf school friendly beach near Ericeira?",
#         "What's the best beach for surfing during low tide around Lisbon?",
#         "Can you recommend a spot with good facilities and accessible waves?"
#     ],
#     "answers": [
#         "Foz do Lizandro is a great choice; it offers consistent beach breaks with multiple peaks, providing both lefts and rights, especially at low to mid tide.",
#         "For beginners, Praia Grande is ideal with a sandy bottom and usually fun and easy waves when they're smaller. It's perfect for surf schools and learning.",
#         "Costa da Caparica works well all year round and at all tides. You’ll find a variety of surf spots suitable for different levels, making it a great option near Lisbon.",
#         "Praia do Baleal Sul is perfect for intermediate surfers looking for less crowded conditions with multiple peaks, near the more relaxed south side.",
#         "For long and hollow lefts, Foz do Lizandro is your spot, especially at the river mouth, where the cliffs provide good shelter from the wind.",
#         "Praia do Baleal Norte offers both lefts and rights with forgiving waves, suitable for all surf levels, making it great for a group of friends.",
#         "Praia Grande features multiple peaks and consistently picks up swell, providing a beach break that works with different tides.",
#         "Foz do Lizandro is known for being beginner-friendly with sandy bottoms and often hosts surf schools due to its fun and manageable waves.",
#         "Praia dos Pescadores is best for low tide when other spots are maxed out. It's a mellow beach break with a sandy bottom, suitable for all surf levels.",
#         "Praia da Torre has great facilities and mellow waves on the right conditions, plus it has a sandy bottom, making it accessible for all surfers."
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "Where can I find a spot with both lefts and rights and a sandy bottom that's suitable for beginners?",
#         "I'm looking for a powerful right-hander with some barrel sections for advanced surfers. Any recommendations?",
#         "What's the best spot for intermediate surfers seeking consistent waves with both directions near Ericeira?",
#         "Can you recommend a break with hollow lefts that works well at mid tide and has high localism?",
#         "Is there a beach break around Lisbon with multiple peaks for all surf levels?",
#         "What are the best surf spots in the Peniche area for advanced surfers with good local conditions?",
#         "Where can I find a less crowded beach break with fun waves suitable for all levels?",
#         "I'm interested in a right point break with powerful barrels and strong localism. Which spot should I consider?",
#         "Can you suggest a fun, mellow wave suitable for intermediate surfers near Coimbra?",
#         "Which surf spot offers the best barrels but is only accessible for experienced surfers?"
#     ],
#     "answers": [
#         "For a beginner-friendly spot with both lefts and rights on a sandy bottom, Foz do Lizandro is a great choice. This beach break is normally best from low to mid tide and is popular among surf schools due to its easy waves.",
#         "You should check out Praia de Santo Amaro. This powerful right point break offers barrel sections over a reef plateau and is best suited for advanced surfers. It works well during mid tide and needs a significant swell to start working.",
#         "Ribeira d’Ilhas is perfect for intermediate surfers looking for consistent waves. This long and mellow righthand point break is accessible at all tides and provides a good mix of fun. Just be ready for a bit of crowding.",
#         "Pedra Branca is known for its fast and hollow lefts, ideal for pro surfers. It requires mid to high tide and has a very high sense of localism, making it an exclusive spot for those who can handle the challenge.",
#         "Costa da Caparica is your go-to beach break that caters to all surf levels. With multiple peaks along its 30-kilometer stretch, it can work at all tides, but mid to high is generally preferred due to consistent wave action.",
#         "In Peniche, Supertubos is the pinnacle for advanced surfers. This world-class beach break is famous for its heavy tubes and can be challenging on bigger days, accessing the best barrels during mid to high tide.",
#         "Praia do Baleal Sul features multiple peaks ideal for all surf levels. It tends to be less crowded, especially at the south side of the beach, and can work well from mid-low to mid-high tide with varying wave sizes.",
#         "Coxos is a legendary spot for a perfect right point break. It's powerful with long, fast, hollow barrels, suited for pro surfers with a high sense of localism, advised to be surfed during low to mid tide for the best experience.",
#         "For a mellow wave that's accommodating for intermediate surfers, check out Praia do Pico da Mota. It's known for its fast and fun waves and can work at mid tide, making it a good pick for a relaxed session.",
#         "Backdoor is a great option for experienced surfers looking for barrels. This consistent righthander surfed best at mid tide provides speed for maneuvers and can produce fun tubes, but isn't for the faint-hearted."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "Where can I find a left and right wave with a sandy bottom?",
#         "I'm looking for a spot to surf both left and right waves next weekend, any suggestions?",
#         "Which surf spots near Ericeira are good for intermediate surfers?",
#         "Can you recommend a beach break with consistent waves for all skill levels?",
#         "What are the best surf spots for barrels and high-quality waves?",
#         "I'm a beginner; where can I surf with left and right options on sandy bottoms?",
#         "Which location is best for experienced surfers looking for hollow waves?",
#         "Are there any spots with both lefts and rights that are less crowded?",
#         "I want a surf spot with good facilities and options for all levels, any ideas?",
#         "Where can I catch waves with moderate crowd levels and beautiful scenery?"
#     ],
#     "answers": [
#         "Foz do Lizandro is your best bet, featuring a variety of peaks with both lefts and rights on a sandy bottom, making it ideal for surfing at low to mid tide.",
#         "Matadouro offers a-frame waves with nice lefts and rights, perfect for the weekend. Surfable from mid to high tide, it has a moderate crowd factor.",
#         "Ribeira dâ€™Ilhas is a fantastic option for intermediates, providing consistent right-handed waves and a relaxed vibe. It works best around mid tide.",
#         "Praia Grande is the go-to beach break for surfers of all levels, with multiple peaks and great facilities. Best surfed from mid tide to high tide, it gets crowded but is worth it.",
#         "Coxos is known for its powerful barrels and is one of the best waves around. Although best for expert surfers, it also has a stunning setting that can't be beaten.",
#         "Prainha at Praia do Baleal Norte is perfect for beginners, offering forgiving waves that break both left and right over a sandy bottom, surfable at all tides.",
#         "Cave is ideal for experienced surfers hunting for hollow right-hand barrels. It's a heavy wave with tricky take-offs, so be prepared.",
#         "Praia de Carcavelos has multiple peaks for left and right options while being less crowded in the southern sections. It's always worth exploring further south.",
#         "Costa da Caparica offers all-level surf options with excellent facilities, making it perfect for everyone looking to enjoy some fun waves.",
#         "Areia Branca provides consistent waves with beautiful scenery perfect for surfing, having a moderate crowd factor and a great vibe for a day out."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "Where can I find a left and right wave suitable for all surf levels?",
#         "What spot offers a good left barrel with high localism?",
#         "I'm an intermediate surfer looking for a mellow left; any recommendations?",
#         "Which spot has a consistent beach break and high crowd factor?",
#         "Can you suggest a powerful right point break for advanced surfers?",
#         "Where is a good surf spot with a sandy bottom and moderate localism?",
#         "What's a good location for experienced surfers that can handle big swells?",
#         "I want a surf spot with both lefts and rights that is less crowded.",
#         "Are there any spots with a sand bottom suitable for beginners in Ericeira?",
#         "What locations work best at mid tide with a mix of left and right waves?"
#     ],
#     "answers": [
#         "Ribeira dâ€™Ilhas is perfect for you! It offers both left and right waves, is suitable for all surf levels, and works well at mid to high tide.",
#         "You might want to check out Moita or Esquerda Moita. Both provide a good left barrel but come with heavy localism, so be prepared to respect the local crew.",
#         "Matadouro is an ideal option for intermediate surfers wanting mellow lefts. It has easy access and is best surfed during mid to high tide.",
#         "Foz do Lizandro is a great choice for consistent beach breaks with multiple peaks. It has a high crowd factor and generally fun waves for everyone.",
#         "Molho Leste is a solid recommendation for advanced surfers, known for its powerful right point break that can offer impressive barrels.",
#         "Praia de Carcavelos or Costa da Caparica provide nice sandy bottoms and moderate localism, suitable for various surf levels.",
#         "Coxos is a great choice if you're looking for a powerful wave that can handle big swells. It's recommended for expert surfers only.",
#         "You’ll enjoy Praia das Amoeiras, which offers both lefts and rights but usually has fewer crowds, located close to Santa Cruz.",
#         "For beginners, Praia do Sul has a sand bottom and is accessible. It offers both lefts and rights, but is better suited to higher swells.",
#         "Limipicos is a good fit; it works best around mid to high tide and provides both lefts and rights over a flat stone reef, suited for intermediate to expert surfers."
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "What are the best left-hand waves to surf in the Ericeira area?",
#         "Can you recommend a spot for advanced surfers looking for barrels?",
#         "Where can I find left-handers that break over a reef near São João do Estoril?",
#         "I'm looking for less crowded surf spots with good local vibes, any suggestions?",
#         "What's the wave consistency like at Crazy Left?",
#         "Are there any good spots to surf during mid tide with a left-hander?",
#         "Where can I find powerful left-handers with excellent barrels?",
#         "Is Esquerda Moita suitable for intermediate surfers?",
#         "What’s the crowd factor like at Papucos, and should I be prepared for rips?",
#         "Which spot has the highest sense of localism among the recommendations?"
#     ],
#     "answers": [
#         "In the Ericeira area, you can check out Papucos and Pedra Branca for some of the best left-hand waves. Both spots offer unique challenges and are suited for advanced surfers, especially under the right conditions.",
#         "For advanced surfers looking for barrels, Pedra Branca is an excellent choice with its powerful reef break and awesome tubes. Just be mindful of the crowded take-off zone and respect the locals!",
#         "Praia da Azarujinha is your go-to for left-hand waves breaking over a reef, located near São João do Estoril. It’s less consistent than Praia da Poça but can produce fun waves, especially around mid tide.",
#         "If you're seeking less crowded surf spots with good local vibes, consider Crazy Left or Praia da Azarujinha. Both spots typically have a low crowd factor and a high sense of localism, so be respectful while you’re out there.",
#         "Crazy Left has moderate consistency and is best surfed at higher tides. It’s known for its fast barrels, but be cautious as the conditions can be tricky.",
#         "Definitely! Both Papucos and Praia da Azarujinha offer left-hand waves that are best surfed at mid tide, making them great options for your session.",
#         "For powerful left-handers with excellent barrels, Pedra Branca stands out as possibly the best in the area. Just make sure you're prepared for the challenges that come with its strong currents and localism.",
#         "Esquerda Moita is best suited for pro surfers due to its fast take-off and shallow nature. While intermediate surfers may be eager to try, caution is advised as it’s accessible primarily for those with advanced skills.",
#         "Papucos has a moderate crowd factor, but be prepared to share the lineup with bodyboarders. When the waves get bigger, watch out for the rips to ensure your safety.",
#         "Among the recommendations, Esquerda Moita displays the highest sense of localism, so prepare to respect the local surfer culture if you decide to give it a go."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "What are some good left-hand surf spots with sand and reef bottoms?",
#         "Can you recommend a spot for intermediate surfers looking for lefts?",
#         "Where can I find hollow barrel waves that break to the left?",
#         "What's the best time to surf at Praia da Azarujinha?",
#         "Is there a surf spot with a low crowd factor that's good for advanced surfers?",
#         "What should I expect at Papucos for wave conditions?",
#         "Are there any spots around Ericeira that offer quality left-hand barrels?",
#         "What type of surfers is Pedra Branca best suited for?",
#         "How do the tides affect Crazy Left for surfing?",
#         "Can you give me tips on localism before surfing at Esquerda Moita?"
#     ],
#     "answers": [
#         "For left-hand surf spots with sand and reef bottoms, check out Praia da Azarujinha and Papucos. Azarujinha provides quality left-hand waves over a reef, while Papucos offers hollow lefts on a flat rock bottom, perfect for experienced surfers.",
#         "Praia da Azarujinha is a solid choice for intermediate surfers seeking lefts, especially around mid tide. It provides fun waves with lower crowd levels.",
#         "If you’re seeking hollow barrel waves that break to the left, head to Papucos, which can produce nice, short barrels when conditions align.",
#         "The best time to surf at Praia da Azarujinha is between October to March. Aim for mid tide for optimal conditions.",
#         "Papucos offers a moderate crowd factor and is best surfed during mid tide for advanced surfers looking for left-hand waves.",
#         "At Papucos, expect moderate consistency with tricky take-offs close to the rocks; be cautious of rips, especially when the waves are bigger.",
#         "In the Ericeira area, Pedra Branca is highly regarded for its quality left-hand barrels, but it's best suited for pro surfers due to its challenging conditions and strong localism.",
#         "Pedra Branca is surfable during mid-high tide and offers powerful waves, so be sure to manage your timing carefully for optimal riding.",
#         "When surfing Esquerda Moita, respect the locals and adhere to surf etiquette as the localism is very high, making it crucial for an enjoyable experience.",
#         "Crazy Left is best surfed at mid-high tide. Keep an eye on the wind conditions for a solid surf session as it can be quite inconsistent."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "What are the conditions like at Praia da Azarujinha for intermediate surfers this week?",
#         "Are there any left-hand waves breaking at Papucos this weekend?",
#         "How does the wave at Esquerda Moita compare for pro surfers?",
#         "What time of tide is best for surfing Pedra Branca right now?",
#         "Can beginners handle the waves at Crazy Left, or is it too advanced?",
#         "What’s the crowd situation like at Praia da Azarujinha on a good surf day?",
#         "How consistent are the waves at Papucos for the upcoming swell?",
#         "Is it worth checking out Pedra Branca for barrel surfers today?",
#         "What are the local conditions like at Crazy Left for expert surfers?",
#         "Are there any safety concerns for bodyboarders at Papucos?"
#     ],
#     "answers": [
# ...
#         "What spots should I consider for experienced surfers wanting barreling waves?",
#         "Which surf spot has the least crowd factor but is good for advanced surfers?",
#         "What are the tide conditions like for Molho Leste?",
#         "Is there a good spot north of town that’s accessible for good intermediates?",
#         "What is the crowd factor like at Ribeira d'Ilhas?"
#     ],
#     "answers": [
#         "For right-hand waves with a sand bottom, Molho Leste is a top choice, offering good barrels for intermediate to advanced surfers. It's best surfed at mid to high tide with a powerful right point break off a jetty.",
#         "Paparucos is an excellent spot for intermediate surfers. It’s a right-hander that breaks over reef and can be surfed at mid to high tide. Conditions are typically easy-going, making it a fun choice for those progressing in their skills.",
#         "Praia de Santo Amaro is your go-to for a powerful right point break. It's hollow and provides multiple barrel sections over a reef plateau. It's best suited for advanced surfers, especially from mid tide onwards.",
#         "The best time to surf Paparucos is during mid to high tide, when the wave offers fun sections with the right swell direction and conditions. Just keep in mind that the entry and exit can be tricky at high tide.",
#         "If you're looking for high localism, Moita is a strong contender. It has heavy localism, but the forgiving right-hand waves can be accessed by good intermediates. Just remember to respect the surf etiquette.",
#         "Cave is perfect for experienced surfers wanting barreling waves. It's a powerful right barrel, but be warned—it’s only for true professionals due to its dangerous nature. Aim to surf it during mid to high tide.",
#         "Molho Leste has a low crowd factor and is suitable for intermediate-advanced to expert-pro surfers. It needs a big swell to start working and is most fun during mid to high tide.",
#         "Molho Leste works best at mid to high tide, making it a reliable spot for good barrels as it breaks off a jetty while being sheltered from northern winds.",
#         "Moita, located just north of town, offers a more forgiving wave that’s accessible for good intermediates. Just take care during lower tides as it gets shallow.",
#         "Ribeira d'Ilhas is one of the most famous surf spots in Portugal, and it tends to be very crowded. However, the long, mellow right point break makes it accessible for surfers of all levels."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "What are the best surf spots for experienced surfers with right-hand waves?",
#         "I'm looking for a consistent right hand break near Peniche.",
#         "Can I find a good surf spot with a sandy bottom that's suitable for intermediates?",
#         "Is there a right point break challenging enough for advanced surfers?",
#         "What surf spots have high localism I should be cautious of?",
#         "Where can I surf a good right barrel in Ericeira?",
#         "Are there any mellow right-hand waves for beginners around here?",
#         "What's the best tide for surfing at Paparucos?",
#         "Can you recommend a spot with powerful right-hand waves?",
#         "What's the crowd situation like at Moita?"
#     ],
#     "answers": [
#         "For experienced surfers, Coxos and Cave in Ericeira are superb options offering challenging right-hand point breaks with powerful conditions. Just make sure to respect the locals and be prepared for some heavy waves.",
#         "Molho Leste is an excellent right point break near Peniche that can deliver great barrels, especially for advanced surfers when the swell is up. Remember, it can attract fierce local surfers, so approach with respect.",
#         "Paparucos has a sandy bottom and is accessible for beginner intermediates, particularly when it's smaller. It's a fun wave that can be enjoyed without too much intimidation, making it a great choice for intermediates.",
#         "Check out Cave for a thrilling experience. Known for its heavy, hollow right barrels, it's best suited for advanced to expert surfers looking for a challenge.",
#         "Moita has a heavy localism, so it's wise to observe surf etiquette and respect the locals if you decide to take on the A-frame wave there.",
#         "For a thrilling right barrel, Coxos is a top choice in Ericeira. With its consistent, powerful rights, you can score some unforgettable rides, just be cautious of its high localism.",
#         "While Paparucos is on the friendlier side with sand bottom access, it's still best for intermediate surfers. If you're a beginner, consider grabbing a lesson at Ribeira d’Ilhas, where conditions are also more forgiving.",
#         "Paparucos is best surfed during mid to high tide. This is when the conditions align for a more enjoyable and safe surfing experience.",
#         "If you’re after powerful right-hand waves, Praia de Santo Amaro delivers some of the best when conditions are right, offering barrel sections over a reef plateau for advanced surfers.",
#         "Moita tends to have a moderate crowd, especially due to its appeal to advanced surfers. If you want a slightly less crowded experience, consider heading to Paparucos during weekdays."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "What's the best surf spot for intermediates looking for right-hand waves?",
#         "I want to surf a powerful right point break, any recommendations?",
#         "Where can I find a righthander with good barrels around here?",
#         "Are there any surf spots with moderate crowds and nice right waves?",
#         "What's the surf level like at Paparucos?",
#         "How's the wave consistency at Moita for someone looking to surf?",
#         "Can you suggest a place for advanced surfers who enjoy reef breaks?",
#         "What tides are best for surfing at Praia de Santo Amaro?",
#         "Are there any lesser-known rights that locals favor?",
#         "What's the crowd factor like at Ribeira d’Ilhas?"
#     ],
#     "answers": [
#         "Paparucos is a great choice for intermediates. It’s a righthander breaking over a flat reef, with easy access and fun sections. Mid to high tide usually offers the best conditions.",
#         "If you're looking for a powerful right point break, Praia de Santo Amaro is your spot. It offers hollow and powerful waves with multiple barrel sections over a reef, perfect for advanced surfers. Mid tide is best!",
#         "Check out Molho Leste for quality righthanders and exciting barrels, especially during bigger swells. This spot is great for intermediate to advanced surfers and works well from mid-high tide.",
#         "In terms of moderate crowds with nice right waves, Moita offers a forgiving right with decent quality that’s also accessible for good intermediates. Just remember to respect the locals as there's high localism.",
#         "Paparucos is suitable for intermediate to expert surfers. Although it has some challenging sections, the overall vibe is pretty easy-going if you know what you're doing.",
#         "Moita typically has moderate consistency, making it a reliable spot for advanced surfers. Just be cautious about lower tides since it can get shallow there.",
#         "For advanced surfers who enjoy challenging reef breaks, Cave is a must-try. It has one of the heaviest waves in Ericeira, perfect for professionals looking for an adrenaline-filled session.",
#         "At Praia de Santo Amaro, mid to high tide works best for surfing. The waves are most consistent during swell events, particularly from October to March.",
#         "If you're looking for lesser-known rights, Inatel might be it. It’s a secretive spot that breaks under specific conditions and has a moderate local presence.",
#         "Ribeira d’Ilhas is one of the most popular surf spots and tends to be very crowded, especially on good swell days. You’ll find various peaks to spread the crowd, though."
#     ]
# }
# ```
# JSON parsing failed on attempt 1. Response: ```json
# {
#     "queries": [
#         "Where can I find fun right-handers with a sandy bottom for intermediate surfers?",
#         "I'm looking for a challenging right-hander with good barrels. Any recommendations?",
#         "What spot would be best for an experienced surfer looking for a powerful wave?",
#         "I want to surf a mellow right wave with a sand bottom this weekend.",
#         "What are the best right-handed breaks around Ericeira for advanced surfers?",
#         "Can you suggest a right point break that works well with mid to high tides?",
#         "Which spots are less crowded for right-hand surfing near Peniche?",
#         "Is there a spot where I can find quality right waves with high localism?",
#         "What's the best time to surf Praia de Santo Amaro?",
#         "I need a good spot that offers consistent right-hand waves but less localism."
#     ],
#     "answers": [
#         "Check out Paparucos! It's a fun right-hander with a mix of sand and rocks, perfect for intermediate surfers, especially around mid to high tide.",
#         "If you're after a powerful right-hander with good barrels, Praia de Santo Amaro is your best bet. This spot offers hollow, powerful waves that are great for advanced surfers, especially from mid tide onwards.",
#         "Molho Leste is a fantastic choice for experienced surfers seeking a powerful right point break. It breaks off a jetty and can offer amazing barrels when the swell is right.",
#         "For a mellow right wave, try Ribeira d’Ilhas. It's a long, easy-going right-hand point break that caters to all levels, though be aware of the crowds during peak times.",
#         "Coxos is a stunning right point break that works best for advanced surfers—expect to encounter locals, especially since it's known for its fast and hollow waves.",
#         "Pontinha is an excellent right-handed spot that works best around mid to high tide, offering a good blend of challenge and fun for advanced surfers.",
#         "If you're looking for surfs with less crowd but not compromising on quality, try Backdoor, which is a consistent righthander that accommodates intermediate to advanced levels.",
#         "The right at Moita has high localism, but if you're experienced and respectful, you can enjoy this great wave. It works well from mid to high tide.",
#         "The best time to surf Praia de Santo Amaro is from October to March when the conditions align perfectly, offering some of the best rights around.",
#         "Consider Limipicos for reliable right-hand waves that are often less crowded. This spot is great for intermediate to expert surfers and works well around mid to high tide."
#     ]
# }
# ```
# JSON parsing failed on attempt 2. Response: ```json
# {
#     "queries": [
#         "Where can I find a fun right-handed wave for intermediate surfers?",
#         "I'm looking for a powerful right point break, what do you recommend?",
#         "What spots have good right-hand waves for experts only?",
#         "Can I surf Paparucos at all tides or is there a best time?",
#         "Which surf spots are known for heavy localism among right-handers?",
#         "What is the best time of year to catch waves at Praia de Santo Amaro?",
#         "Where can I find a consistent right reef break that is also not too crowded?",
#         "Looking for a righthander that works well at mid tide with barrels?",
#         "What is the surf level required for surfing Molho Leste?",
#         "How is the crowd situation at Ribeira dâ€™Ilhas compared to other spots?"
#     ],
#     "answers": [
#         "Paparucos is a great choice for intermediate surfers! It operates well at mid to high tide and offers fun right-hand sections with an easy-going vibe overall.",
#         "You might want to check out Coxos, a powerful right point break that's well-known for its hollow barrels. It's best suited for experts and can hold some big swells!",
#         "Cave is the wave you're looking for if you're seeking a challenging right with intense barrels. It's highly recommended but only for expert surfers!",
#         "You can surf Paparucos at all tides, but the best conditions are generally found at mid to high tide. Just keep in mind that high tide can make getting out tricky.",
#         "Be careful at Moita and Molho Leste if you're not experienced with localism; both spots have heavy local influence and respect is crucial!",
#         "Praia de Santo Amaro is best surfed from October to March when the swells are big enough for its powerful right point break to come alive. Make sure you're prepared!",
#         "For a less crowded right reef break, try Limipicos. It's a great spot that works with mid to high tides and offers reliable surf when the conditions are right.",
#         "Backdoor is an excellent spot if you're seeking right-hand barrels that work well at mid tide. It's forgiving for intermediates up to a meter high, so enjoy!",
#         "Molho Leste is best suited for intermediate to advanced surfers, especially when the waves get big. Expect some fierce local competition during those sessions.",
#         "Ribeira dâ€™Ilhas can be quite crowded since it's one of the most iconic surf spots in Portugal, but don’t worry, there are typically several peaks to spread out the surfers."
#     ]
# }
# ```
# JSON parsing failed on attempt 3. Response: ```json
# {
#     "queries": [
#         "Where can I find a fun right-hand wave for intermediate surfers?",
#         "What’s a good surf spot with a sandy bottom and manageable waves for beginners?",
#         "Can you recommend a powerful right break suitable for advanced surfers?",
#         "What’s the best spot for hollow barrels on the right in Ericeira?",
#         "Where can I surf with minimal crowd but still have fun waves?",
#         "Is there a reliable right-hand point break for pro surfers in Portugal?",
#         "What are the tide conditions for surfing at Praia de Santo Amaro?",
#         "Where can I surf in Peniche with a sandy bottom and good local vibes?",
#         "Can you tell me about surf spots that can handle big swells?",
#         "What’s the local scene like at Molho Leste in Peniche?"
#     ],
#     "answers": [
#         "Check out Paparucos! It’s a fun righthander that can be enjoyed by intermediate surfers. It works well at mid to high tide and the vibe is generally easy-going.",
#         "For beginner-friendly waves, consider Backdoor. This right-hander features a sandy bottom and works well under intermediate surfers up to a meter, making it perfect for a relaxed session.",
#         "If you’re looking for a powerful right break, Praia de Santo Amaro is ideal for advanced surfers. It’s a long powerful point break with multiple barrel sections, best from mid tide onwards.",
#         "Coxos is the spot for hollow barrels! It’s a renowned right point break that works best at low tide, providing long, fast, and hollow waves when the conditions are right.",
#         "Molho Leste offers a good balance of fun waves and a less crowded experience. It can provide solid rights that are suitable for intermediate-advanced surfers when conditions align.",
#         "Check out Cave if you’re looking for challenging conditions! This heavy right barrel is perfect for pro surfers and works well at mid-high tide.",
#         "At Praia de Santo Amaro, the best tide conditions are mid to high tide to catch those barrels. It's best surfed from October to March.",
#         "Molho Leste is a great surf spot to enjoy righthanders with a sandy bottom, and although it has a fierce local crowd, respect will get you far there.",
#         "For big swells, Cave is a top spot; it requires significant west swells to break properly, making it suitable for experienced riders looking for challenges.",
#         "Molho Leste has a strong sense of localism, so be prepared to share the waves respectfully with locals, who can be quite fierce from time to time."
#     ]
# }
# ```
# Ground truth dataset successfully created and saved.

# %%
final_truth_df.to_csv("ground_truth_rag_surf.csv", index=False)
final_truth_df.to_json("ground_truth_rag_surf.json", orient="records", indent=4)
